# %%
#Import Dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file = "Exchange_Rate_Report1.csv"
foreign_ex = pd.read_csv(file)
foreign_ex
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 0                                                   NaN
# 1                                                  Date
# 2                                           29-Apr-2013
# 3                                           30-Apr-2013
# 4                                            1-May-2013
# ...                                                 ...
# 1980                 The International Monetary Fund...
# 1981                 implied, regarding these tables...
# 1982                 The Fund shall not be liable fo...
# 1983                 in connection with this site.  ...
# 1984                                                NaN
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1     Australian dollar   (AUD)
# 2                                             1.0312
# 3                                             1.0368
# ...

# %%
foreign_ex.columns
# Out:
# Index(['Representative rates for the period  April 28, 2013 - March 23, 2021',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
foreign_ex = foreign_ex.rename(columns={'Unnamed: 1': 'Australian Dollar (AUD)', 'Unnamed: 2': 'Chinese Yuan (CNY)', 'Unnamed: 3': 'Euro (EUR)', 'Unnamed: 4': 'Japanese Yen (JPY)', 'Unnamed: 5': 'Swiss Franc (CHF)', 'Unnamed: 6':'U.K. Pound (GBP)', 'Unnamed: 7': 'U.S. Dollar (USD)'})
foreign_ex
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 0                                                   NaN
# 1                                                  Date
# 2                                           29-Apr-2013
# 3                                           30-Apr-2013
# 4                                            1-May-2013
# ...                                                 ...
# 1980                 The International Monetary Fund...
# 1981                 implied, regarding these tables...
# 1982                 The Fund shall not be liable fo...
# 1983                 in connection with this site.  ...
# 1984                                                NaN
#
#                              Australian Dollar (AUD)  \
# 0                                                NaN
# 1     Australian dollar   (AUD)
# 2                                             1.0312
# 3                                             1.0368
# ...

# %%
foreign_ex.columns
# Out:
# Index(['Representative rates for the period  April 28, 2013 - March 23, 2021',
#        'Australian Dollar (AUD)', 'Chinese Yuan (CNY)', 'Euro (EUR)',
#        'Japanese Yen (JPY)', 'Swiss Franc (CHF)', 'U.K. Pound (GBP)',
#        'U.S. Dollar (USD)'],
#       dtype='object')

# %%
foreign_ex_1 = foreign_ex.drop([0, 1])
foreign_ex_1
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 2                                           29-Apr-2013
# 3                                           30-Apr-2013
# 4                                            1-May-2013
# 5                                            2-May-2013
# 6                                            3-May-2013
# ...                                                 ...
# 1980                 The International Monetary Fund...
# 1981                 implied, regarding these tables...
# 1982                 The Fund shall not be liable fo...
# 1983                 in connection with this site.  ...
# 1984                                                NaN
#
#      Australian Dollar (AUD) Chinese Yuan (CNY) Euro (EUR) Japanese Yen (JPY)  \
# 2                     1.0312                NaN     1.3113                NaN
# 3                     1.0368                NaN     1.3072              97.91
# ...

# %%
clean_foreign_ex = foreign_ex_1.drop(foreign_ex_1.index[1965:1984])
clean_foreign_ex
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 2                                           29-Apr-2013
# 3                                           30-Apr-2013
# 4                                            1-May-2013
# 5                                            2-May-2013
# 6                                            3-May-2013
# ...                                                 ...
# 1962                                        16-Mar-2021
# 1963                                        17-Mar-2021
# 1964                                        18-Mar-2021
# 1965                                        19-Mar-2021
# 1966                                        22-Mar-2021
#
#      Australian Dollar (AUD) Chinese Yuan (CNY) Euro (EUR) Japanese Yen (JPY)  \
# 2                     1.0312                NaN     1.3113                NaN
# 3                     1.0368                NaN     1.3072              97.91
# ...

# %%
clean_foreign_ex
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 2                                           29-Apr-2013
# 3                                           30-Apr-2013
# 4                                            1-May-2013
# 5                                            2-May-2013
# 6                                            3-May-2013
# ...                                                 ...
# 1962                                        16-Mar-2021
# 1963                                        17-Mar-2021
# 1964                                        18-Mar-2021
# 1965                                        19-Mar-2021
# 1966                                        22-Mar-2021
#
#      Australian Dollar (AUD) Chinese Yuan (CNY) Euro (EUR) Japanese Yen (JPY)  \
# 2                     1.0312                NaN     1.3113                NaN
# 3                     1.0368                NaN     1.3072              97.91
# ...

# %%
clean_foreign_ex = clean_foreign_ex.reset_index()

# %%
clean_foreign_ex.columns
# Out:
# Index(['index',
#        'Representative rates for the period  April 28, 2013 - March 23, 2021',
#        'Australian Dollar (AUD)', 'Chinese Yuan (CNY)', 'Euro (EUR)',
#        'Japanese Yen (JPY)', 'Swiss Franc (CHF)', 'U.K. Pound (GBP)',
#        'U.S. Dollar (USD)'],
#       dtype='object')

# %%
clean_foreign_ex = clean_foreign_ex[['Representative rates for the period  April 28, 2013 - March 23, 2021',
       'Australian Dollar (AUD)', 'Chinese Yuan (CNY)', 'Euro (EUR)',
       'Japanese Yen (JPY)', 'Swiss Franc (CHF)', 'U.K. Pound (GBP)',
       'U.S. Dollar (USD)']]
clean_foreign_ex
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 0                                           29-Apr-2013
# 1                                           30-Apr-2013
# 2                                            1-May-2013
# 3                                            2-May-2013
# 4                                            3-May-2013
# ...                                                 ...
# 1960                                        16-Mar-2021
# 1961                                        17-Mar-2021
# 1962                                        18-Mar-2021
# 1963                                        19-Mar-2021
# 1964                                        22-Mar-2021
#
#      Australian Dollar (AUD) Chinese Yuan (CNY) Euro (EUR) Japanese Yen (JPY)  \
# 0                     1.0312                NaN     1.3113                NaN
# 1                     1.0368                NaN     1.3072              97.91
# ...

# %%
clean_foreign_ex.dtypes
# Out:
# Representative rates for the period  April 28, 2013 - March 23, 2021    object
# Australian Dollar (AUD)                                                 object
# Chinese Yuan (CNY)                                                      object
# Euro (EUR)                                                              object
# Japanese Yen (JPY)                                                      object
# Swiss Franc (CHF)                                                       object
# U.K. Pound (GBP)                                                        object
# U.S. Dollar (USD)                                                       object
# dtype: object

# %%
clean_foreign_ex['Australian Dollar (AUD)'] = clean_foreign_ex['Australian Dollar (AUD)'].astype(float)

# %%
clean_foreign_ex['Chinese Yuan (CNY)'] = clean_foreign_ex['Chinese Yuan (CNY)'].astype(float)

# %%
clean_foreign_ex['Euro (EUR)'] = clean_foreign_ex['Euro (EUR)'].astype(float)

# %%
clean_foreign_ex['Japanese Yen (JPY)'] = clean_foreign_ex['Japanese Yen (JPY)'].astype(float)

# %%
clean_foreign_ex['Swiss Franc (CHF)'] = clean_foreign_ex['Swiss Franc (CHF)'].astype(float)

# %%
clean_foreign_ex['U.K. Pound (GBP)'] = clean_foreign_ex['U.K. Pound (GBP)'].astype(float)

# %%
clean_foreign_ex['U.S. Dollar (USD)'] = clean_foreign_ex['U.S. Dollar (USD)'].astype(float)

# %%
#Mean for AUD, CNY, EUR, JPY, CHF, GBP

AUD_mean = clean_foreign_ex['Australian Dollar (AUD)'].mean()
print(f"The mean for AUD is {AUD_mean}")
# Out:
# The mean for AUD is 0.7731068217874141

# %%
CNY_mean = clean_foreign_ex['Chinese Yuan (CNY)'].mean()
print(f"The mean for CNY is {CNY_mean}")
# Out:
# The mean for CNY is 6.559191176470573

# %%
EURO_mean = clean_foreign_ex['Euro (EUR)'].mean()
print(f"The mean for EURO is {EURO_mean}")
# Out:
# The mean for EURO is 1.175835309278348

# %%
JPY_mean = clean_foreign_ex['Japanese Yen (JPY)'].mean()
print(f"The mean for JPY is {JPY_mean}")
# Out:
# The mean for JPY is 109.46898924731171

# %%
CHF_mean = clean_foreign_ex['Swiss Franc (CHF)'].mean()
print(f"The mean for CHF is {CHF_mean}")
# Out:
# The mean for CHF is 0.9603364412070758

# %%
GBP_mean = clean_foreign_ex['U.K. Pound (GBP)'].mean()
print(f"The mean for GBP is {GBP_mean}")
# Out:
# The mean for GBP is 1.403978494069109

# %%
USD_mean = clean_foreign_ex['U.S. Dollar (USD)'].mean()
print(f"The mean for USD is {USD_mean}")
# Out:
# The mean for USD is 1.0

# %%
cleaned_foreign_ex = clean_foreign_ex.fillna(method='ffill')
cleaned_foreign_ex
# Out:
#      Representative rates for the period  April 28, 2013 - March 23, 2021  \
# 0                                           29-Apr-2013
# 1                                           30-Apr-2013
# 2                                            1-May-2013
# 3                                            2-May-2013
# 4                                            3-May-2013
# ...                                                 ...
# 1960                                        16-Mar-2021
# 1961                                        17-Mar-2021
# 1962                                        18-Mar-2021
# 1963                                        19-Mar-2021
# 1964                                        22-Mar-2021
#
#       Australian Dollar (AUD)  Chinese Yuan (CNY)  Euro (EUR)  \
# 0                      1.0312                 NaN      1.3113
# 1                      1.0368                 NaN      1.3072
# 2                      1.0367                 NaN      1.3072
# ...

# %%
# Push the remade DataFrame to a new CSV file
cleaned_foreign_ex.to_csv("cleaned_foreign_ex.csv",
                  encoding="utf-8", index=False, header=True)

# %%
#Fluctuations
cleaned_foreign_ex.plot(x="Representative rates for the period April 28, 2013 - March 23, 2021",y="Australian Dollar (AUD)", rot=45)
plt.xlabel("Date",size=16)
plt.ylabel("AUD",size=16)
plt.title("AUD Fluctuations", size=18)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Representative rates for the period April 28, 2013 - March 23, 2021'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
